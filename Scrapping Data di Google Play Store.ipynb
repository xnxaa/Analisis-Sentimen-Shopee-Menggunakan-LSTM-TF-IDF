# %%
# !pip install google_play_scraper

from google_play_scraper import app

import pandas as pd

import numpy as np
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.shopee.id',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=3000,
)

# %%
df = pd.DataFrame(np.array(result),columns=['review'])

df = df.join(pd.DataFrame(df.pop('review').tolist()))

df.head()
# Out:
#                                reviewId         userName  \
# 0  512980dc-b5d6-4c40-874e-43d723c1a7c5  Pengguna Google
# 1  97419223-d675-4325-aeec-aa477fb22f43  Pengguna Google
# 2  6eb967ea-b7b3-4b14-8b82-7450fd2e0214  Pengguna Google
# 3  312320fa-7953-472d-be3c-cce948054693  Pengguna Google
# 4  375373a6-df5b-42ae-a898-c85186df1c8d  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Ekpedisi spx sekarang lelet banget.. Spx hemat...      2            103
# 1  Dari aplikasi belanjanya sebenarnya paling dis...      4            112
# 2  Sekarang lemot banget, respon lama, tombol bac...      1            153
# 3  aplikasi sekarang sudah bagus gak lambat loadi...      1             53
# 4  Susah bgt mau ganti/tukar akun shopee setelah ...      1             18
#
#   reviewCreatedVersion                  at  \
# 0              3.33.50 2024-09-04 01:47:20
# 1              3.33.50 2024-09-05 06:51:15
# 2              3.33.50 2024-09-04 02:51:36
# 3              3.33.50 2024-09-03 21:36:55
# 4              3.32.19 2024-09-05 17:48:33
#
#                                         replyContent           repliedAt  \
# 0  Hi kak, maaf ya atas kendala terkait pemilihan... 2024-09-04 02:26:11
# 1  Hai kak, terimakasih ya buat review dan bintan... 2024-09-05 07:34:01
# 2  Hai kak, maaf ya bikin cemas. terkait kendala ... 2022-09-26 18:03:11
# 3  Hi kak, maaf uda buat km ga nyaman terkait ken... 2024-09-03 22:59:40
# 4  hi kak, maaf ya untuk kendala pada aplikasi sh... 2024-09-03 16:32:16
#
#   appVersion
# 0    3.33.50
# 1    3.33.50
# 2    3.33.50
# 3    3.33.50
# 4    3.32.19

# %%
df[['userName', 'score','at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Pengguna Google      2 2024-09-04 01:47:20
# 1  Pengguna Google      4 2024-09-05 06:51:15
# 2  Pengguna Google      1 2024-09-04 02:51:36
# 3  Pengguna Google      1 2024-09-03 21:36:55
# 4  Pengguna Google      1 2024-09-05 17:48:33
#
#                                              content
# 0  Ekpedisi spx sekarang lelet banget.. Spx hemat...
# 1  Dari aplikasi belanjanya sebenarnya paling dis...
# 2  Sekarang lemot banget, respon lama, tombol bac...
# 3  aplikasi sekarang sudah bagus gak lambat loadi...
# 4  Susah bgt mau ganti/tukar akun shopee setelah ...

# %%
new_df = df[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#             userName  score                  at  \
# 4    Pengguna Google      1 2024-09-05 17:48:33
# 76   Pengguna Google      5 2024-09-05 13:17:42
# 923  Pengguna Google      3 2024-09-05 13:05:10
# 15   Pengguna Google      5 2024-09-05 12:55:11
# 787  Pengguna Google      1 2024-09-05 12:18:35
#
#                                                content
# 4    Susah bgt mau ganti/tukar akun shopee setelah ...
# 76   Inii kenapa yaa Sudah 2 hari ini shopee saya t...
# 923  Bintang 3 dulu karena banyak penjual penipu de...
# 15   Belanja di shopee bener2 buat nagih ya... Sela...
# 787  Notif shopee lu ngerepotin bangett njirr.. set...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']]

# %%
my_df.to_csv("data_shopee.csv", index = False)
